# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexanderNikolaevich1983/-/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22hw_4_1_%D0%91%D0%B0%D0%B7%D0%BE%D0%B2%D1%96_%D0%B2%D1%96%D0%B7%D1%83%D0%B0%D0%BB%D1%96%D0%B7%D0%B0%D1%86%D1%96%D1%97_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Домашнє завдання №1 до модуля 4: Базові візуалізації даних.

# %% [markdown]
# В цьому ДЗ ми потренуємось будувати базові візуалізації з бібліотекою matplotlib.

# %% [markdown]
# 0. Імпортуйте модуль matplotlib.pyplot для роботи як це показано у лекції. Імпортуйте також numpy, він нам знадобиться.

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt # or from matplotlib import.pyplot as plt

# %% [markdown]
# ### Завдання 1: Візуалізація лінійної та квадратичної функцій
#
# **Мета:** Побудувати графіки лінійної та квадратичної функцій на одному графіку для порівняння їх поведінки.
#
# 1. Створіть масив значень `x` від -10 до 10 (включно) так, аби масив налічував 200 точок (інакше кажучи, мав крок 0.1 від точки до точки) використовуючи спеціальну функцію `numpy`.

# %%
import numpy as np

x = np.linspace(-10, 10, 200)

print(x[:10])
print(f"Довжина масиву: {len(x)}")
# Out:
# [-10.          -9.89949749  -9.79899497  -9.69849246  -9.59798995
#   -9.49748744  -9.39698492  -9.29648241  -9.1959799   -9.09547739]
# Довжина масиву: 200

# %% [markdown]
# 2. Створіть змінну `y_linear`, яка буде містити результат обчислення лінійної функції `y = 2x + 1`. Враховуйте, що змінну `x` ми створили з `numpy`, а значить для арифметичних обчислень з нею нам не треба цикл, бо можемо працювати з цыэю змінною, як з вектором (так само, як працюємо з колонками в `pandas`)

# %%
y_linear = 2 * x + 1

print(y_linear[:10])
# Out:
# [-19.         -18.79899497 -18.59798995 -18.39698492 -18.1959799
#  -17.99497487 -17.79396985 -17.59296482 -17.3919598  -17.19095477]

# %% [markdown]
# 3. Створіть змінну, яка буде містити результат обчислення квадратичної функції `y = x^2 - x - 2`.

# %%
y_quadratic = x**2 - x - 2
print(y_quadratic[:10])
# Out:
# [108.         105.89954799 103.81929749 101.7592485   99.71940103
#   97.69975506  95.7003106   93.72106765  91.76202621  89.82318628]

# %% [markdown]
# 4. Побудуйте лінійну візуалізацію значень змінної `y_linear` за відповідних значень `x`.

# %%
import matplotlib.pyplot as plt

# Побудова графіка для y_linear
plt.plot(x, y_linear, label="y = 2x + 1", color="blue")

# Додаткові елементи для графіка
plt.title("Графік лінійної функції")
plt.xlabel("x")
plt.ylabel("y")
plt.grid(True)
plt.legend()

# Відображення графіка
plt.show()

# %% [markdown]
# 5. Побудуйте лінійну візуалізацію значень змінної `y_quadratic` за відповідних значень x.

# %%
import matplotlib.pyplot as plt

# Побудова графіка для y_quadratic
plt.plot(x, y_quadratic, label="y = x² - x - 2", color="red")  # Лінійний графік

# Додаткові елементи для графіка
plt.title("Графік квадратичної функції")  # Назва графіка
plt.xlabel("x")  # Підпис осі x
plt.ylabel("y")  # Підпис осі y
plt.grid(True)  # Увімкнення сітки
plt.legend()  # Додати легенду

# Відображення графіка
plt.show()

# %% [markdown]
# 6. Побудуйте графіки обох функцій на одному графіку:
#    - Використайте червоний колір та суцільну лінію для лінійної функції.
#    - Використайте зелений колір та переривчасту лінію для квадратичної функції.

# %%
import matplotlib.pyplot as plt

# Побудова графіка для лінійної функції
plt.plot(x, y_linear, label="Лінійна: y = 2x + 1", color="red", linestyle="-")

# Побудова графіка для квадратичної функції
plt.plot(x, y_quadratic, label="Квадратична: y = x² - x - 2", color="green", linestyle="--")

# Додаткові елементи для графіка
plt.title("Графіки лінійної та квадратичної функцій")  # Назва графіка
plt.xlabel("x")  # Підпис осі x
plt.ylabel("y")  # Підпис осі y
plt.grid(True)  # Увімкнення сітки
plt.legend()  # Додати легенду

# Відображення графіка
plt.show()

# %% [markdown]
# Виглядає непогано! Але давайте для солідності додамо підписи графіку і на осях, а також сітку і легенду. Про це буде в наступному уроці, а поки просто вставте замість трьох крапок спочатку наповнення (те, що на попередньому кроці було всередині p для побудови графіку лінійної фукнції, потім - квадратичної і запустіть код.

# %%
plt.plot(x, y_linear, label="Лінійна функція", color="red", linestyle="-")
plt.plot(x, y_quadratic, label="Квадратична функція", color="green", linestyle="--")

plt.title("Порівняння лінійної та квадратичної функцій")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid(True)

plt.show()
